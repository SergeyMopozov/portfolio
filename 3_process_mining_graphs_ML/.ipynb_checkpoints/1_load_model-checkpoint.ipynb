# %% [markdown]
# # Graph nodes load prediction
#
# В общей постановке задача формулируется следующим образом:
# 1. Существует набор каким-то образом взаимосвязанных объектов, которые можно представить в виде графовой структуры (перекрестки и автомобильные дороги, цепочки поставок, складская логистическая инфраструктура, сетевое оборудование, набор датчиков и пр.). Причем сами объекты моделируется как узлы графа, а их взаимосвязи как ребра.
# 2. В каждом узле с определенной периодичностью измеряется значение некоего сигнала/сигналов (количество и скорость автомобилей, количетво сетевых пакетов, объуем грузов, напряжение, вибрации или метеорологические параметры)
# 3. В случае если источник сигнала распорстраняющийся по графу можно идентифицировать (автомобили, сетевые пакеты и пр.) это дает возможность идентифицировать структуру графа. В противном случае структура графа должна быть определена заранее (как например со структурой датчиков, сейсмологических или метеорологических станций и пр.)
# 4. Необходимо определить значение сигнла/сигналов во всех узлах графа (количество атомобилий скопившихся на перекрестке, количество просмотров "постов" в соцсети, переполнение склада в аэропорту  и пр.)

# %%
# Вариант №1 решение задачи управление
# 1. Построение графа
# 2. Данные по времени перемещениям между узлами графа и обработки в узлах 
# 3. Моделирование распределений времени перемещений и обработки
# 4. Построение маршрутов на графе
# 5. Данные по активности пользователей на вершинах графа
# 6. Моделирование загрузки распределительных центров в зависимости от пользовательской активности
#    и распределения времени перемещения и обраотки

# %%
# Вариант №2 решение задачи статистического моделирования
# 1. Построение графа
# 2. Данные по расстоянию/времени/типу перемещений между узлами графа
# 3. Моделирование распределений времени перемещений и обработки
# 4. Построение модели StellarGraph прогнозирования временных рядов на граффах (GNN LTSM)
# 5. Анализ результатов прогнозирования
